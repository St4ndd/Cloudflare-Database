# %% [markdown]
# <a href="https://colab.research.google.com/github/St4ndd/Cloudflare-Database/blob/main/ComfyUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Installation von ComfyUI und Abhängigkeiten
# %cd /content
# !git clone https://github.com/comfyanonymous/ComfyUI
# %cd /content/ComfyUI
# !pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu121
# !pip install -r requirements.txt
# !pip install aiohttp pyngrok

# 2. Wichtige Custom Nodes installieren (Manager & VideoHelperSuite)
# %cd /content/ComfyUI/custom_nodes
# !git clone https://github.com/ltdrdata/ComfyUI-Manager
# !git clone https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite
# !pip install -r ComfyUI-VideoHelperSuite/requirements.txt
# %cd /content/ComfyUI
# Out:
# /content
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 29097, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 29097 (delta 43), reused 30 (delta 30), pack-reused 29035 (from 4)
# Receiving objects: 100% (29097/29097), 75.59 MiB | 22.51 MiB/s, done.
# Resolving deltas: 100% (19721/19721), done.
# /content/ComfyUI
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu121
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.0/19.0 MB 77.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 88.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 118.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 73.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 MB 16.5 MB/s eta 0:00:00
# ...

# %%
# @title 📥 Checkpoint Downloader
# 1. In den Checkpoints-Ordner wechseln
# %cd /content/ComfyUI/models/checkpoints

# @markdown ---
# 4. Juggernaut XL Parameter
download_checkpoint = True # @param {type:"boolean"}
checkpoint_url = "https://model-download.cdn2.seaart.ai/static/checkpoint/20251021/4e58044b8592ba579051903f70141159.safetensors?Expires=1767810132&KeyName=seaart-model-key&Signature=qbiQKXwVxXZ7evIDzck9AKBqcZOMgRM_dDth2D5tdDb7ycuw_ubAdEXZ-5Hbw3bzYHkI25gEg4R3_bhd-5wCBw==" # @param {type:"string"}
file_name = "cyberrealistic.safetensors" # @param {type:"string"}

if download_checkpoint:
  # Das '$' Zeichen vor der Variable ist wichtig!
  # !wget -c -O {file_name} {checkpoint_url}

print("Download completed!")
# Out:
# /content/ComfyUI/models/checkpoints
# --2026-01-07 19:35:24--  https://model-download.cdn2.seaart.ai/static/checkpoint/20251021/4e58044b8592ba579051903f70141159.safetensors?Expires=1767810132
# Resolving model-download.cdn2.seaart.ai (model-download.cdn2.seaart.ai)... 34.104.36.235, 2600:1900:4110:8b8::
# Connecting to model-download.cdn2.seaart.ai (model-download.cdn2.seaart.ai)|34.104.36.235|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2026-01-07 19:35:24 ERROR 403: Forbidden.
#
# Download completed!

# %%
# 3. NGROK TUNNEL SETUP
import os
from pyngrok import ngrok

# %cd /content/ComfyUI

# --- SETZE HIER DEINEN NGROK TOKEN EIN ---
NGROK_AUTH_TOKEN = "1szMKu8NZwKMWKICYEKjbmIY51z_3zQ6D3Hk3cdHhzCnLXMS2"
# -----------------------------------------

ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Tunnel erstellen für Port 8188
public_url = ngrok.connect(8188)
print(f"\n[!] DEINE COMFYUI URL: {public_url}\n")

# 4. START COMFYUI
# !python main.py --dont-print-server
# Out:
# [!] DEINE COMFYUI URL: NgrokTunnel: "https://ce29fd9e5b06.ngrok-free.app" -> "http://localhost:8188"
#
# python3: can't open file '/content/ComfyUI/models/checkpoints/main.py': [Errno 2] No such file or directory
